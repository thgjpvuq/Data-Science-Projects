# %%
import pandas as pd

# %%
d = pd.read_csv('artwork_sample.csv')

# %%
d.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
d.medium
# Out:
# 0    Watercolour, ink, chalk and graphite on paper....
# 1                                    Graphite on paper
# 2          Graphite on paper. Verso: graphite on paper
# 3                                    Graphite on paper
# 4                              Line engraving on paper
# 5                              Line engraving on paper
# 6                              Line engraving on paper
# 7                              Line engraving on paper
# 8                              Line engraving on paper
# 9                              Line engraving on paper
# Name: medium, dtype: object

# %%
type(d.medium)
# Out:
# pandas.core.series.Series

# %%
d.medium.str

# %%
d.medium.str.contains('Graphite')
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: medium, dtype: bool

# %%
d.loc[d.medium.str.contains('Graphite'), ['artist', 'medium']]
# Out:
#           artist                                       medium
# 1  Blake, Robert                            Graphite on paper
# 2  Blake, Robert  Graphite on paper. Verso: graphite on paper
# 3  Blake, Robert                            Graphite on paper

# %%
d.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
d.loc[d.medium.str.contains('Graphite', case=False), ['artist', 'medium']]
# Out:
#           artist                                             medium
# 0  Blake, Robert  Watercolour, ink, chalk and graphite on paper....
# 1  Blake, Robert                                  Graphite on paper
# 2  Blake, Robert        Graphite on paper. Verso: graphite on paper
# 3  Blake, Robert                                  Graphite on paper

# %%
d.loc[d.medium.str.contains('(?i)Graphite', regex=True), ['artist', 'medium']]
# Out:
#           artist                                             medium
# 0  Blake, Robert  Watercolour, ink, chalk and graphite on paper....
# 1  Blake, Robert                                  Graphite on paper
# 2  Blake, Robert        Graphite on paper. Verso: graphite on paper
# 3  Blake, Robert                                  Graphite on paper

# %%
d.loc[d.medium.str.contains('(?i)Graphite', regex=True) | d.medium.str.contains('(?i)Line', regex=True), ['artist', 'medium']]
# Out:
#            artist                                             medium
# 0   Blake, Robert  Watercolour, ink, chalk and graphite on paper....
# 1   Blake, Robert                                  Graphite on paper
# 2   Blake, Robert        Graphite on paper. Verso: graphite on paper
# 3   Blake, Robert                                  Graphite on paper
# 4  Blake, William                            Line engraving on paper
# 5  Blake, William                            Line engraving on paper
# 6  Blake, William                            Line engraving on paper
# 7  Blake, William                            Line engraving on paper
# 8  Blake, William                            Line engraving on paper
# 9  Blake, William                            Line engraving on paper

# %%
d.loc[d.medium.str.contains('graphite|line', case=False, regex=True), ['artist', 'medium']]
# Out:
#            artist                                             medium
# 0   Blake, Robert  Watercolour, ink, chalk and graphite on paper....
# 1   Blake, Robert                                  Graphite on paper
# 2   Blake, Robert        Graphite on paper. Verso: graphite on paper
# 3   Blake, Robert                                  Graphite on paper
# 4  Blake, William                            Line engraving on paper
# 5  Blake, William                            Line engraving on paper
# 6  Blake, William                            Line engraving on paper
# 7  Blake, William                            Line engraving on paper
# 8  Blake, William                            Line engraving on paper
# 9  Blake, William                            Line engraving on paper

# %%
d.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                  float64
# acquisitionYear         int64
# dimensions             object
# width                   int64
# height                  int64
# depth                 float64
# units                  object
# inscription           float64
# thumbnailCopyright    float64
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
d.year.astype(str).str.contains('1826')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: year, dtype: bool

# %%
d.loc[d.year.astype(str).str.contains('1826')]
# Out:
#      id accession_number          artist artistRole  artistId  \
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
# 5      Ciampolo the Barrator Tormented by the Devils  1826–7, reprinted 1892
# 6                        The Baffled Devils Fighting  1826–7, reprinted 1892
# 7  The Six-Footed Serpent Attacking Agnolo Brunel...  1826–7, reprinted 1892
# 8                 The Serpent Attacking Buoso Donati  1826–7, reprinted 1892
# ...

# %%
d = pd.read_csv('artwork_data.csv', low_memory=False)

# %%
d.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
d.loc[d.dimensions.str.contains('support')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ENLARG~1\AppData\Local\Temp/ipykernel_10420/2518386137.py in <module>
# ----> 1 d.loc[d.dimensions.str.contains('support')]
#
# C:\Users\EnlargedSquash\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# C:\Users\EnlargedSquash\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1141             self._validate_key(key, axis)
#    1142             return self._get_slice_axis(key, axis=axis)
# -> 1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
# ...

# %%
d.loc[d.dimensions.str.contains('support', na=False)]
# Out:
#            id accession_number            artist artistRole  artistId  \
# 0        1035           A00001     Blake, Robert     artist        38
# 1        1036           A00002     Blake, Robert     artist        38
# 2        1037           A00003     Blake, Robert     artist        38
# 3        1038           A00004     Blake, Robert     artist        38
# 32       1067           A00033    Blake, William     artist        39
# ...       ...              ...               ...        ...       ...
# 69170  121195           T13839  Barlow, Phyllida     artist     10908
# 69171  121196           T13840  Barlow, Phyllida     artist     10908
# 69172  121197           T13841  Barlow, Phyllida     artist     10908
# 69173  121198           T13842  Barlow, Phyllida     artist     10908
# 69178  121565           T13847    Walker, Kelley     artist     16207
#
#                                                    title           dateText  \
# ...
